# %% [markdown]
# ## DETECTION OF DUPLICATES

# %%
import pandas as pd
alphabet= pd.DataFrame(['a','b','c','c','d','c','f','g','g','g'],columns=['Alphabet'])

# %%
alphabet
# Out:
#   Alphabet
# 0        a
# 1        b
# 2        c
# 3        c
# 4        d
# 5        c
# 6        f
# 7        g
# 8        g
# 9        g

# %%
alphabet.duplicated(keep=False)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8     True
# 9     True
# dtype: bool

# %%
alphabet.duplicated(keep='first')
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# 9     True
# dtype: bool

# %%
alphabet[alphabet.duplicated(keep=False)]  # shows all duplicates
# Out:
#   Alphabet
# 2        c
# 3        c
# 5        c
# 7        g
# 8        g
# 9        g

# %%
alphabet[alphabet.duplicated(keep='first')]  # keeps the first and count the second and onword as duplicate
# Out:
#   Alphabet
# 3        c
# 5        c
# 8        g
# 9        g

# %% [markdown]
# #### On Titanic dataset

# %%
titanic=pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# survived    891 non-null int64
# pclass      891 non-null int64
# sex         891 non-null object
# age         714 non-null float64
# sibsp       891 non-null int64
# parch       891 non-null int64
# fare        891 non-null float64
# embarked    889 non-null object
# deck        203 non-null object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.duplicated(keep='first').sum()
# Out:
# 107

# %%
titanic[titanic.duplicated(keep='first')]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 47          1       3  female   NaN      0      0   7.7500        Q  NaN
# 76          0       3    male   NaN      0      0   7.8958        S  NaN
# 77          0       3    male   NaN      0      0   8.0500        S  NaN
# 87          0       3    male   NaN      0      0   8.0500        S  NaN
# 95          0       3    male   NaN      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 870         0       3    male  26.0      0      0   7.8958        S  NaN
# 877         0       3    male  19.0      0      0   7.8958        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
#
# [107 rows x 9 columns]

# %% [markdown]
# #### Summer dataset

# %%
summer=pd.read_csv('summer.csv')

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
# Year          31165 non-null int64
# City          31165 non-null object
# Sport         31165 non-null object
# Discipline    31165 non-null object
# Athlete       31165 non-null object
# Country       31161 non-null object
# Gender        31165 non-null object
# Event         31165 non-null object
# Medal         31165 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.duplicated(keep='first').sum()
# Out:
# 2

# %%
summer[summer.duplicated(keep=False)]   #Below data show real duplicates
# Out:
#        Year    City      Sport Discipline       Athlete Country Gender  \
# 16098  1980  Moscow     Hockey     Hockey  SINGH, Singh     IND    Men
# 16099  1980  Moscow     Hockey     Hockey  SINGH, Singh     IND    Men
# 29779  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
# 29785  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
#
#          Event Medal
# 16098   Hockey  Gold
# 16099   Hockey  Gold
# 29779  Doubles  Gold
# 29785  Doubles  Gold

# %%
summer.loc[(summer.Sport=='Badminton')&(summer.Year==2012)]  #filtering the df to find duplicates in the data.
# Out:
#        Year    City      Sport Discipline               Athlete Country  \
# 29772  2012  London  Badminton  Badminton              CAI, Yun     CHN
# 29773  2012  London  Badminton  Badminton           FU, Haifeng     CHN
# 29774  2012  London  Badminton  Badminton          BOE, Mathias     DEN
# 29775  2012  London  Badminton  Badminton     MOGENSEN, Carsten     DEN
# 29776  2012  London  Badminton  Badminton        CHUNG, Jaesung     KOR
# 29777  2012  London  Badminton  Badminton         LEE, Yong Dae     KOR
# 29778  2012  London  Badminton  Badminton            TIAN, Qing     CHN
# 29779  2012  London  Badminton  Badminton          ZHAO, Yunlei     CHN
# 29780  2012  London  Badminton  Badminton         FUJII, Mizuki     JPN
# 29781  2012  London  Badminton  Badminton        KAKIIWA, Reika     JPN
# 29782  2012  London  Badminton  Badminton     SOROKINA, Valeria     RUS
# 29783  2012  London  Badminton  Badminton         VISLOVA, Nina     RUS
# ...

# %% [markdown]
# ### Handling / Removing Duplicates

# %% [markdown]
# #### Titanic dataset

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
titanic.duplicated().sum()
# Out:
# 107

# %%
titanic[titanic.duplicated()].head(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 47          1       3  female   NaN      0      0   7.7500        Q  NaN
# 76          0       3    male   NaN      0      0   7.8958        S  NaN
# 77          0       3    male   NaN      0      0   8.0500        S  NaN
# 87          0       3    male   NaN      0      0   8.0500        S  NaN
# 95          0       3    male   NaN      0      0   8.0500        S  NaN
# 101         0       3    male   NaN      0      0   7.8958        S  NaN
# 121         0       3    male   NaN      0      0   8.0500        S  NaN
# 133         1       2  female  29.0      1      0  26.0000        S  NaN
# 173         0       3    male  21.0      0      0   7.9250        S  NaN
# 196         0       3    male   NaN      0      0   7.7500        Q  NaN

# %%
titanic.drop(index=[77,87,95],inplace=True)

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 5         0       3    male   NaN      0      0   8.4583        Q  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 7         0       3    male   2.0      3      1  21.0750        S  NaN
# 8         1       3  female  27.0      0      2  11.1333        S  NaN
# 9         1       2  female  14.0      1      0  30.0708        C  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 888 entries, 0 to 890
# Data columns (total 9 columns):
# survived    888 non-null int64
# pclass      888 non-null int64
# sex         888 non-null object
# age         714 non-null float64
# sibsp       888 non-null int64
# parch       888 non-null int64
# fare        888 non-null float64
# embarked    886 non-null object
# deck        203 non-null object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 69.4+ KB

# %% [markdown]
# ##### OLYMPIC DATASET

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
# Year          31165 non-null int64
# City          31165 non-null object
# Sport         31165 non-null object
# Discipline    31165 non-null object
# Athlete       31165 non-null object
# Country       31161 non-null object
# Gender        31165 non-null object
# Event         31165 non-null object
# Medal         31165 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.duplicated(keep=False).sum()
# Out:
# 4

# %%
summer[summer.duplicated(keep=False)]
# Out:
#        Year    City      Sport Discipline       Athlete Country Gender  \
# 16098  1980  Moscow     Hockey     Hockey  SINGH, Singh     IND    Men
# 16099  1980  Moscow     Hockey     Hockey  SINGH, Singh     IND    Men
# 29779  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
# 29785  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
#
#          Event Medal
# 16098   Hockey  Gold
# 16099   Hockey  Gold
# 29779  Doubles  Gold
# 29785  Doubles  Gold

# %%
summer.drop(index=[16098,16099,29779,29785],inplace=True)

# %%
summer.duplicated(keep=False).sum()
# Out:
# 0

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31161 entries, 0 to 31164
# Data columns (total 9 columns):
# Year          31161 non-null int64
# City          31161 non-null object
# Sport         31161 non-null object
# Discipline    31161 non-null object
# Athlete       31161 non-null object
# Country       31157 non-null object
# Gender        31161 non-null object
# Event         31161 non-null object
# Medal         31161 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.4+ MB

# %%
##Alphabet duplicate

alphabet[alphabet.duplicated(keep=False)]
# Out:
#   Alphabet
# 2        c
# 3        c
# 5        c
# 7        g
# 8        g
# 9        g

# %%
alphabet.drop_duplicates(inplace=True)   # drop_duplicated - used to drop the duplicates

# %%
alphabet
# Out:
#   Alphabet
# 0        a
# 1        b
# 2        c
# 4        d
# 6        f
# 7        g

# %% [markdown]
# ### Ignore_index parameter in drop duplicate method

# %%
alphabet= pd.DataFrame(['a','b','c','c','d','c','f','g','g','g'],columns=['Alphabet'])

# %%
alphabet
# Out:
#   Alphabet
# 0        a
# 1        b
# 2        c
# 3        c
# 4        d
# 5        c
# 6        f
# 7        g
# 8        g
# 9        g

# %%
alphabet.drop_duplicates()
# Out:
#   Alphabet
# 0        a
# 1        b
# 2        c
# 4        d
# 6        f
# 7        g

# %% [markdown]
# ## Detection of Outliers

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  888.000000  888.000000  714.000000  888.000000  888.000000  888.000000
# mean     0.385135    2.306306   29.699118    0.524775    0.382883   32.285810
# std      0.486901    0.836515   14.526497    1.104186    0.807113   49.757502
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.456250
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.068750
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,8))
titanic.boxplot('age')
plt.show()

# %%
plt.figure(figsize=(12,8))
titanic.age.plot()
plt.show()

# %%
titanic.age.sort_values(ascending=False)
# Out:
# 630    80.0
# 851    74.0
# 96     71.0
# 493    71.0
# 116    70.5
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: age, Length: 888, dtype: float64

# %%
titanic.loc[titanic.age>75]
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked deck
# 630         1       1  male  80.0      0      0  30.0        S    A

# %%
titanic.fare.sort_values(ascending=False)
# Out:
# 737    512.3292
# 679    512.3292
# 258    512.3292
# 88     263.0000
# 341    263.0000
#          ...
# 277      0.0000
# 633      0.0000
# 302      0.0000
# 597      0.0000
# 271      0.0000
# Name: fare, Length: 888, dtype: float64

# %%
plt.figure(figsize=(12,8))
titanic.fare.plot()
plt.show()

# %%
plt.figure(figsize=(12,8))
titanic.boxplot('fare')
plt.show()

# %% [markdown]
# ### Handling / Removing Outliers

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.loc[titanic.age>75]  # Considering 80 age passenger as a outlier.
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked deck
# 630         1       1  male  80.0      0      0  30.0        S    A

# %%
index_out1= titanic.loc[titanic.age>75].index

# %%
index_out1
# Out:
# Int64Index([630], dtype='int64')

# %%
titanic.loc[titanic.age>75,"age"]=titanic.loc[titanic.age>75,'age']-10

# %%
titanic.loc[index_out1]
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked deck
# 630         1       1  male  70.0      0      0  30.0        S    A

# %%
titanic.loc[630,'age']=65.0

# %%
titanic.loc[index_out1]
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked deck
# 630         1       1  male  65.0      0      0  30.0        S    A

# %%
plt.figure(figsize=(12,8))
titanic.age.plot()
plt.show()

# %% [markdown]
# ## Categorical Data

# %%
titanic=pd.read_csv("titanic.new.csv")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
# Unnamed: 0    894 non-null int64
# Survived      894 non-null int64
# Class         894 non-null int64
# Gender        894 non-null object
# Age           894 non-null float64
# SipSp         894 non-null int64
# ParCh         894 non-null int64
# Fare          894 non-null float64
# Enb           892 non-null object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 63.0+ KB

# %%
titanic.to_csv("titanic_clean.csv",index=False)

# %%
titanic
# Out:
#      Unnamed: 0  Survived  Class  Gender   Age  SipSp  ParCh     Fare Enb
# 0             0         0      3    male  22.0      1      0   7.2500   S
# 1             1         1      1  female  38.0      1      0  71.2833   C
# 2             2         1      3  female  26.0      0      0   7.9250   S
# 3             3         1      1  female  35.0      1      0  53.1000   S
# 4             4         0      3    male  35.0      0      0   8.0500   S
# ..          ...       ...    ...     ...   ...    ...    ...      ...  ..
# 889         889         1      1    male  26.0      0      0  30.0000   C
# 890         890         0      3    male  32.0      0      0   7.7500   Q
# 891         891         0      2    male  24.0      0      0  10.5000   S
# 892         892         0      3    male  34.0      1      1  14.4000   S
# 893         893         0      3    male  36.0      0      0   7.8958   S
#
# [894 rows x 9 columns]

# %%
titanic.nunique()
# Out:
# Unnamed: 0    894
# Survived        2
# Class           3
# Gender          2
# Age            92
# SipSp           7
# ParCh           7
# Fare          248
# Enb             3
# dtype: int64

# %%
titanic[["Gender","Enb"]].describe()
# Out:
#        Gender  Enb
# count     894  892
# unique      2    3
# top      male    S
# freq      580  647

# %%
titanic.columns
# Out:
# Index(['Unnamed: 0', 'Survived', 'Class', 'Gender', 'Age', 'SipSp', 'ParCh',
#        'Fare', 'Enb'],
#       dtype='object')

# %%
titanic.Gender= titanic.Gender.astype("category")

# %%
titanic.Enb=titanic.Enb.astype("category")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
# Unnamed: 0    894 non-null int64
# Survived      894 non-null int64
# Class         894 non-null int64
# Gender        894 non-null category
# Age           894 non-null float64
# SipSp         894 non-null int64
# ParCh         894 non-null int64
# Fare          894 non-null float64
# Enb           892 non-null category
# dtypes: category(2), float64(2), int64(5)
# memory usage: 51.0 KB

# %% [markdown]
# #### Olympic Dataset

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31161 entries, 0 to 31164
# Data columns (total 9 columns):
# Year          31161 non-null int64
# City          31161 non-null object
# Sport         31161 non-null object
# Discipline    31161 non-null object
# Athlete       31161 non-null object
# Country       31157 non-null object
# Gender        31161 non-null object
# Event         31161 non-null object
# Medal         31161 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.4+ MB

# %%
summer.to_csv("titanic_clean.csv",index=False)

# %%
summer.describe(include=["O"])   #include ='O' is for selecting only objects.
# Out:
#           City     Sport Discipline          Athlete Country Gender     Event  \
# count    31161     31161      31161            31161   31157  31161     31161
# unique      22        43         67            22760     147      2       666
# top     London  Aquatics  Athletics  PHELPS, Michael     USA    Men  Football
# freq      3565      4170       3638               22    4585  22744      1497
#
#         Medal
# count   31161
# unique      3
# top      Gold
# freq    10482

# %%
summer.nunique()
# Out:
# Year             27
# City             22
# Sport            43
# Discipline       67
# Athlete       22760
# Country         147
# Gender            2
# Event           666
# Medal             3
# dtype: int64

# %%
summer.City= summer.City.astype('category')

# %%
summer.Sport=summer.Sport.astype("category")

# %%
summer.Discipline=summer.Discipline.astype("category")

# %%
summer.Country=summer.Country.astype("category")

# %%
summer.Gender=summer.Gender.astype("category")

# %%
summer.Medal=summer.Medal.astype("category")

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31161 entries, 0 to 31164
# Data columns (total 9 columns):
# Year          31161 non-null int64
# City          31161 non-null category
# Sport         31161 non-null category
# Discipline    31161 non-null category
# Athlete       31161 non-null object
# Country       31157 non-null category
# Gender        31161 non-null category
# Event         31161 non-null object
# Medal         31161 non-null category
# dtypes: category(6), int64(1), object(2)
# memory usage: 1.2+ MB

# %% [markdown]
# ### New dtypes and pd.NA  # for PANDAS VER.1.0

# %%
titanic=pd.read_csv("titanic.csv")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# survived    891 non-null int64
# pclass      891 non-null int64
# sex         891 non-null object
# age         714 non-null float64
# sibsp       891 non-null int64
# parch       891 non-null int64
# fare        891 non-null float64
# embarked    889 non-null object
# deck        203 non-null object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
#titanic=titanic.convert_dtypes()   #  converts the datatype from int64 to Int64 and object to string

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.iloc[0,-1]  #it will appear as <NA>
# Out:
# nan

# %%
type(titanic.iloc[0,-1])  # it will show- pandas._libs.missing.NAType
# Out:
# float

# %%
#pd.NA
