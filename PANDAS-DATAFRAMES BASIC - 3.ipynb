# %% [markdown]
# ### Sorting Dataframe with sort_index() and sort_values()

# %%
import pandas as pd

# %%
titanic=pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.age.sort_values()
# Out:
# 803    0.42
# 755    0.67
# 644    0.75
# 469    0.75
# 78     0.83
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: age, Length: 891, dtype: float64

# %%
titanic.sort_values(by='age')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 803         1       3    male  0.42      0      1   8.5167        C  NaN
# 755         1       2    male  0.67      1      1  14.5000        S  NaN
# 644         1       3  female  0.75      2      1  19.2583        C  NaN
# 469         1       3  female  0.75      2      1  19.2583        C  NaN
# 78          1       2    male  0.83      0      2  29.0000        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(by='age',ascending=False, inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 630         1       1    male  80.0      0      0  30.0000        S    A
# 851         0       3    male  74.0      0      0   7.7750        S  NaN
# 493         0       1    male  71.0      0      0  49.5042        C  NaN
# 96          0       1    male  71.0      0      0  34.6542        C    A
# 116         0       3    male  70.5      0      0   7.7500        Q  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(by=['pclass','sex','age'],ascending=True,inplace=True)   # sorting by specific columns

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 297         0       1  female   2.0      1      2  151.5500        S    C
# 435         1       1  female  14.0      1      2  120.0000        S    B
# 689         1       1  female  15.0      0      1  211.3375        S    B
# 853         1       1  female  16.0      0      1   39.4000        S    D
# 329         1       1  female  16.0      0      1   57.9792        C    B
# ..        ...     ...     ...   ...    ...    ...       ...      ...  ...
# 837         0       3    male   NaN      0      0    8.0500        S  NaN
# 846         0       3    male   NaN      8      2   69.5500        S  NaN
# 859         0       3    male   NaN      0      0    7.2292        C  NaN
# 868         0       3    male   NaN      0      0    9.5000        S  NaN
# 878         0       3    male   NaN      0      0    7.8958        S  NaN
#
# [891 rows x 9 columns]

# %%
pd.options.display.max_rows=900   # selecting maximum rows

# %%
titanic
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 297         0       1  female   2.00      1      2  151.5500        S    C
# 435         1       1  female  14.00      1      2  120.0000        S    B
# 689         1       1  female  15.00      0      1  211.3375        S    B
# 853         1       1  female  16.00      0      1   39.4000        S    D
# 329         1       1  female  16.00      0      1   57.9792        C    B
# 504         1       1  female  16.00      0      0   86.5000        S    B
# 781         1       1  female  17.00      1      0   57.0000        S    B
# 307         1       1  female  17.00      1      0  108.9000        C    C
# 700         1       1  female  18.00      1      0  227.5250        C    C
# 585         1       1  female  18.00      0      2   79.6500        S    E
# 311         1       1  female  18.00      2      2  262.3750        C    B
# ...

# %%
titanic.sort_values(by=['pclass','sex','age'],ascending=[True,True,False],inplace=True)   
                                # sorting by specific columns with independant ascending orders

# %%
titanic
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 275         1       1  female  63.00      1      0   77.9583        S    D
# 829         1       1  female  62.00      0      0   80.0000      NaN    B
# 366         1       1  female  60.00      1      0   75.2500        C    D
# 268         1       1  female  58.00      0      1  153.4625        S    C
# 11          1       1  female  58.00      0      0   26.5500        S    C
# 195         1       1  female  58.00      0      0  146.5208        C    B
# 879         1       1  female  56.00      0      1   83.1583        C    C
# 496         1       1  female  54.00      1      0   78.2667        C    D
# 513         1       1  female  54.00      1      0   59.4000        C  NaN
# 571         1       1  female  53.00      2      0   51.4792        S    C
# 820         1       1  female  52.00      1      1   93.5000        S    B
# ...

# %%
titanic.sort_index(ascending=True, inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 0           0       3    male  22.00      1      0    7.2500        S  NaN
# 1           1       1  female  38.00      1      0   71.2833        C    C
# 2           1       3  female  26.00      0      0    7.9250        S  NaN
# 3           1       1  female  35.00      1      0   53.1000        S    C
# 4           0       3    male  35.00      0      0    8.0500        S  NaN
# 5           0       3    male    NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.00      0      0   51.8625        S    E
# 7           0       3    male   2.00      3      1   21.0750        S  NaN
# 8           1       3  female  27.00      0      2   11.1333        S  NaN
# 9           1       2  female  14.00      1      0   30.0708        C  NaN
# 10          1       3  female   4.00      1      1   16.7000        S    G
# ...

# %%
titanic.sort_values(by='age').reset_index(drop=True)   #sort age by values by reseting index keeping drop as true
## Many time index is not important so to keep original index while sorting column ,we use reset_index(drop=True)
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 0           1       3    male   0.42      0      1    8.5167        C  NaN
# 1           1       2    male   0.67      1      1   14.5000        S  NaN
# 2           1       3  female   0.75      2      1   19.2583        C  NaN
# 3           1       3  female   0.75      2      1   19.2583        C  NaN
# 4           1       2    male   0.83      0      2   29.0000        S  NaN
# 5           1       2    male   0.83      1      1   18.7500        S  NaN
# 6           1       1    male   0.92      1      2  151.5500        S    C
# 7           1       2    male   1.00      0      2   37.0042        C  NaN
# 8           1       3  female   1.00      0      2   15.7417        C  NaN
# 9           0       3    male   1.00      4      1   39.6875        S  NaN
# 10          1       2    male   1.00      2      1   39.0000        S    F
# ...

# %% [markdown]
# ### Ranking DataFrame rank ()

# %%
sales=pd.Series([15,32,45,21,55,15,0],index=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])

# %%
sales
# Out:
# Mon    15
# Tue    32
# Wed    45
# Thu    21
# Fri    55
# Sat    15
# Sun     0
# dtype: int64

# %%
sales.sort_values(ascending=False)
# Out:
# Fri    55
# Wed    45
# Tue    32
# Thu    21
# Sat    15
# Mon    15
# Sun     0
# dtype: int64

# %%
sales.rank().sort_values(ascending=True)
# Out:
# Sun    1.0
# Mon    2.5
# Sat    2.5
# Thu    4.0
# Tue    5.0
# Wed    6.0
# Fri    7.0
# dtype: float64

# %%
sales.rank(ascending=False, method='min').sort_values(ascending=True)
# Out:
# Fri    1.0
# Wed    2.0
# Tue    3.0
# Thu    4.0
# Mon    5.0
# Sat    5.0
# Sun    7.0
# dtype: float64

# %%
sales.rank(ascending=False, method='average',pct=True).sort_values()   #pct is for rank in percentiles
# Out:
# Fri    0.142857
# Wed    0.285714
# Tue    0.428571
# Thu    0.571429
# Mon    0.785714
# Sat    0.785714
# Sun    1.000000
# dtype: float64

# %%
titanic
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 0           0       3    male  22.00      1      0    7.2500        S  NaN
# 1           1       1  female  38.00      1      0   71.2833        C    C
# 2           1       3  female  26.00      0      0    7.9250        S  NaN
# 3           1       1  female  35.00      1      0   53.1000        S    C
# 4           0       3    male  35.00      0      0    8.0500        S  NaN
# 5           0       3    male    NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.00      0      0   51.8625        S    E
# 7           0       3    male   2.00      3      1   21.0750        S  NaN
# 8           1       3  female  27.00      0      2   11.1333        S  NaN
# 9           1       2  female  14.00      1      0   30.0708        C  NaN
# 10          1       3  female   4.00      1      1   16.7000        S    G
# ...

# %%
titanic.fare.rank(ascending=False).head()
# Out:
# 0    815.0
# 1    103.0
# 2    659.5
# 3    144.0
# 4    628.0
# Name: fare, dtype: float64

# %%
titanic['fare_rank']=titanic.fare.rank(ascending=False,method='min')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#    fare_rank
# 0      809.0
# 1      103.0
# 2      651.0
# 3      142.0
# 4      607.0

# %%
titanic.sort_values('fare',ascending=False)
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck  \
# 258         1       1  female  35.00      0      0  512.3292        C  NaN
# 737         1       1    male  35.00      0      0  512.3292        C    B
# 679         1       1    male  36.00      0      1  512.3292        C    B
# 88          1       1  female  23.00      3      2  263.0000        S    C
# 27          0       1    male  19.00      3      2  263.0000        S    C
# 341         1       1  female  24.00      3      2  263.0000        S    C
# 438         0       1    male  64.00      1      4  263.0000        S    C
# 311         1       1  female  18.00      2      2  262.3750        C    B
# 742         1       1  female  21.00      2      2  262.3750        C    B
# 118         0       1    male  24.00      0      1  247.5208        C    B
# 299         1       1  female  50.00      0      1  247.5208        C    B
# ...

# %% [markdown]
# ### nunique() and nlargest()/nsmallest() with dataframes

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#    fare_rank
# 0      809.0
# 1      103.0
# 2      651.0
# 3      142.0
# 4      607.0

# %%
titanic.age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
titanic.nunique(axis=0,dropna=False)  #dropna=False i.e we included NaN cvalues in counting
# Out:
# survived       2
# pclass         3
# sex            2
# age           89
# sibsp          7
# parch          7
# fare         248
# embarked       4
# deck           8
# fare_rank    248
# dtype: int64

# %%
titanic.nlargest(n=5,columns='fare')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck  \
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 27          0       1    male  19.0      3      2  263.0000        S    C
# 88          1       1  female  23.0      3      2  263.0000        S    C
#
#      fare_rank
# 258        1.0
# 679        1.0
# 737        1.0
# 27         4.0
# 88         4.0

# %%
titanic.sort_values('fare',ascending=False).head()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck  \
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 88          1       1  female  23.0      3      2  263.0000        S    C
# 27          0       1    male  19.0      3      2  263.0000        S    C
#
#      fare_rank
# 258        1.0
# 737        1.0
# 679        1.0
# 88         4.0
# 27         4.0

# %%
titanic.nsmallest(n=5,columns='age')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 803         1       3    male  0.42      0      1   8.5167        C  NaN
# 755         1       2    male  0.67      1      1  14.5000        S  NaN
# 469         1       3  female  0.75      2      1  19.2583        C  NaN
# 644         1       3  female  0.75      2      1  19.2583        C  NaN
# 78          1       2    male  0.83      0      2  29.0000        S  NaN
#
#      fare_rank
# 803      598.0
# 755      435.0
# 469      381.0
# 644      381.0
# 78       249.0

# %%
titanic.sort_values('age').head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 803         1       3    male  0.42      0      1   8.5167        C  NaN
# 755         1       2    male  0.67      1      1  14.5000        S  NaN
# 644         1       3  female  0.75      2      1  19.2583        C  NaN
# 469         1       3  female  0.75      2      1  19.2583        C  NaN
# 78          1       2    male  0.83      0      2  29.0000        S  NaN
#
#      fare_rank
# 803      598.0
# 755      435.0
# 644      381.0
# 469      381.0
# 78       249.0

# %%
titanic.loc[titanic.age.idxmin()]
# Out:
# survived          1
# pclass            3
# sex            male
# age            0.42
# sibsp             0
# parch             1
# fare         8.5167
# embarked          C
# deck            NaN
# fare_rank       598
# Name: 803, dtype: object

# %% [markdown]
# ### Summery Statistics and Accumulations

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#    fare_rank
# 0      809.0
# 1      103.0
# 2      651.0
# 3      142.0
# 4      607.0

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#         fare_rank
# count  891.000000
# mean   439.961841
# std    254.525014
# min      1.000000
# 25%    223.000000
# 50%    445.000000
# 75%    660.000000
# max    877.000000

# %%
titanic.count(axis=0)
# Out:
# survived     891
# pclass       891
# sex          891
# age          714
# sibsp        891
# parch        891
# fare         891
# embarked     889
# deck         203
# fare_rank    891
# dtype: int64

# %%
titanic.count(axis=1)
# Out:
# 0       9
# 1      10
# 2       9
# 3      10
# 4       9
# 5       8
# 6      10
# 7       9
# 8       9
# 9       9
# 10     10
# 11     10
# 12      9
# 13      9
# 14      9
# 15      9
# 16      9
# 17      8
# 18      9
# 19      8
# 20      9
# 21     10
# 22      9
# 23     10
# 24      9
# 25      9
# 26      8
# 27     10
# 28      8
# 29      8
# 30      9
# 31      9
# 32      8
# 33      9
# 34      9
# 35      9
# 36      8
# 37      9
# 38      9
# 39      9
# 40      9
# 41      9
# 42      8
# 43      9
# 44      9
# 45      8
# 46      8
# 47      8
# 48      8
# 49      9
# 50      9
# 51      9
# 52     10
# 53      9
# 54     10
# 55      9
# 56      9
# 57      9
# 58      9
# 59      9
# 60      9
# 61      9
# 62     10
# 63      9
# 64      8
# 65      8
# 66     10
# 67      9
# 68      9
# 69      9
# 70      9
# 71      9
# 72      9
# 73      9
# 74      9
# 75     10
# 76      8
# 77      8
# 78      9
# 79      9
# 80      9
# 81      9
# 82      8
# ...

# %%
titanic.mean(axis=0)
# Out:
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# fare_rank    439.961841
# dtype: float64

# %%
titanic.mean(axis=1)
# Out:
# 0      120.321429
# 1       30.754757
# 2       98.417857
# 3       33.300000
# 4       93.292857
# 5      101.743050
# 6       37.694643
# 7       55.439286
# 8       81.304757
# 9       40.152971
# 10      60.385714
# 11      50.935714
# 12      91.150000
# 13      42.182143
# 14     105.407743
# 15      68.714286
# 16      40.446429
# 17      80.000000
# 18      63.285714
# 19     141.370833
# 20      51.285714
# 21      73.428571
# 22      96.718457
# 23      37.214286
# 24      56.296429
# 25      41.626786
# 26     141.204167
# 27      41.714286
# 28     119.979867
# 29     113.315967
# 30      47.388686
# 31      29.920133
# 32     127.291667
# 33      86.785714
# 34      26.310114
# 35      35.142857
# 36     138.871533
# 37      91.292857
# 38      61.571429
# 39      79.034529
# 40      89.496429
# 41      59.000000
# 42     113.315967
# 43      31.939886
# 44     105.554171
# 45     103.008333
# 46      72.916667
# 47     127.291667
# 48      63.946533
# 49      61.828571
# ...

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#    fare_rank
# 0      809.0
# 1      103.0
# 2      651.0
# 3      142.0
# 4      607.0

# %%
titanic.fare.cumsum(axis=0)
# Out:
# 0          7.2500
# 1         78.5333
# 2         86.4583
# 3        139.5583
# 4        147.6083
# 5        156.0666
# 6        207.9291
# 7        229.0041
# 8        240.1374
# 9        270.2082
# 10       286.9082
# 11       313.4582
# 12       321.5082
# 13       352.7832
# 14       360.6374
# 15       376.6374
# 16       405.7624
# 17       418.7624
# 18       436.7624
# 19       443.9874
# 20       469.9874
# 21       482.9874
# 22       491.0166
# 23       526.5166
# 24       547.5916
# 25       578.9791
# 26       586.2041
# 27       849.2041
# 28       857.0833
# 29       864.9791
# 30       892.6999
# 31      1039.2207
# 32      1046.9707
# 33      1057.4707
# 34      1139.6415
# 35      1191.6415
# 36      1198.8707
# 37      1206.9207
# 38      1224.9207
# 39      1236.1624
# 40      1245.6374
# 41      1266.6374
# 42      1274.5332
# 43      1316.1124
# 44      1323.9916
# 45      1332.0416
# 46      1347.5416
# 47      1355.2916
# 48      1376.9708
# 49      1394.7708
# ...

# %%
titanic.corr()
# Out:
#            survived    pclass       age     sibsp     parch      fare  \
# survived   1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass    -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age       -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp     -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch      0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare       0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# fare_rank -0.322046  0.700150 -0.116334 -0.357585 -0.366020 -0.639490
#
#            fare_rank
# survived   -0.322046
# pclass      0.700150
# age        -0.116334
# sibsp      -0.357585
# parch      -0.366020
# fare       -0.639490
# fare_rank   1.000000

# %%
titanic.survived.corr(titanic.pclass)
# Out:
# -0.33848103596101475

# %%
titanic.sum(axis=0)
# Out:
# survived                                                   342
# pclass                                                    2057
# sex          malefemalefemalefemalemalemalemalemalefemalefe...
# age                                                    21205.2
# sibsp                                                      466
# parch                                                      340
# fare                                                   28693.9
# fare_rank                                               392006
# dtype: object

# %% [markdown]
# ### agg() Method

# %%
titanic
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck  \
# 0           0       3    male  22.00      1      0    7.2500        S  NaN
# 1           1       1  female  38.00      1      0   71.2833        C    C
# 2           1       3  female  26.00      0      0    7.9250        S  NaN
# 3           1       1  female  35.00      1      0   53.1000        S    C
# 4           0       3    male  35.00      0      0    8.0500        S  NaN
# 5           0       3    male    NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.00      0      0   51.8625        S    E
# 7           0       3    male   2.00      3      1   21.0750        S  NaN
# 8           1       3  female  27.00      0      2   11.1333        S  NaN
# 9           1       2  female  14.00      1      0   30.0708        C  NaN
# 10          1       3  female   4.00      1      1   16.7000        S    G
# ...

# %%
titanic.mean()
# Out:
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# fare_rank    439.961841
# dtype: float64

# %%
titanic.agg('mean')
# Out:
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# fare_rank    439.961841
# dtype: float64

# %%
titanic.agg(['mean','std','min','max','median'])
# Out:
#         survived    pclass     sex        age     sibsp     parch        fare  \
# mean    0.383838  2.308642     NaN  29.699118  0.523008  0.381594   32.204208
# std     0.486592  0.836071     NaN  14.526497  1.102743  0.806057   49.693429
# min     0.000000  1.000000  female   0.420000  0.000000  0.000000    0.000000
# max     1.000000  3.000000    male  80.000000  8.000000  6.000000  512.329200
# median  0.000000  3.000000     NaN  28.000000  0.000000  0.000000   14.454200
#
#          fare_rank
# mean    439.961841
# std     254.525014
# min       1.000000
# max     877.000000
# median  445.000000

# %%
titanic.agg({"survived":"mean","age":["min","max"]})
# Out:
#       survived    age
# max        NaN  80.00
# mean  0.383838    NaN
# min        NaN   0.42

# %% [markdown]
# ### apply(), map() and applymap()

# %%
sales=pd.read_csv('sales.csv')

# %%
sales
# Out:
#   Unnamed: 0  Mon  Tue  Wed   Thu  Fri
# 0     Steven   34   27   15   NaN   33
# 1       Mike   45    9   74  87.0   12
# 2       Andi   17   33   54   8.0   29
# 3       Paul   87   67   27  45.0    7

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
# Unnamed: 0    4 non-null object
# Mon           4 non-null int64
# Tue           4 non-null int64
# Wed           4 non-null int64
# Thu           3 non-null float64
# Fri           4 non-null int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 320.0+ bytes

# %%
sales.min(axis=0)
# Out:
# Unnamed: 0    Andi
# Mon             17
# Tue              9
# Wed             15
# Thu              8
# Fri              7
# dtype: object

# %%
sales.min(axis=1)
# Out:
# 0    15.0
# 1     9.0
# 2     8.0
# 3     7.0
# dtype: float64

# %%
sales.apply(lambda x: x.max() - x.min(),axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     119                 else:
# --> 120                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     121             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in reduction(values, axis, skipna, mask)
#     842         else:
# --> 843             result = getattr(values, meth)(axis)
#     844
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims, initial)
#      27           initial=_NoValue):
# ---> 28     return umr_maximum(a, axis, None, out, keepdims, initial)
#      29
#
# TypeError: '>=' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
summer=pd.read_csv('summer.csv')

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.Athlete.apply(lambda x:x[0])## apply -it is used to apply any function on any method  
# here we used to get first word of the athlete names.
# Out:
# 0        H
# 1        H
# 2        D
# 3        M
# 4        C
#         ..
# 31160    J
# 31161    R
# 31162    T
# 31163    A
# 31164    L
# Name: Athlete, Length: 31165, dtype: object

# %%
summer.Athlete.map(lambda x:x[0])
# Out:
# 0        H
# 1        H
# 2        D
# 3        M
# 4        C
#         ..
# 31160    J
# 31161    R
# 31162    T
# 31163    A
# 31164    L
# Name: Athlete, Length: 31165, dtype: object

# %%
summer.iloc[:,1:3].applymap(lambda x:x[0:2])  #applymap- to apply function on specific columns using iloc.
#here we are selecting two elements of first two column .
# Out:
#       City Sport
# 0       At    Aq
# 1       At    Aq
# 2       At    Aq
# 3       At    Aq
# 4       At    Aq
# ...    ...   ...
# 31160   Lo    Wr
# 31161   Lo    Wr
# 31162   Lo    Wr
# 31163   Lo    Wr
# 31164   Lo    Wr
#
# [31165 rows x 2 columns]

# %% [markdown]
# ### Hierarchical Indexing (Multiindex) (Part-1)

# %%
titanic=pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic=titanic.iloc[:50,:]  # Selected first fifty rows and all columns

# %%
titanic
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 0          0       3    male  22.0      1      0    7.2500        S  NaN
# 1          1       1  female  38.0      1      0   71.2833        C    C
# 2          1       3  female  26.0      0      0    7.9250        S  NaN
# 3          1       1  female  35.0      1      0   53.1000        S    C
# 4          0       3    male  35.0      0      0    8.0500        S  NaN
# 5          0       3    male   NaN      0      0    8.4583        Q  NaN
# 6          0       1    male  54.0      0      0   51.8625        S    E
# 7          0       3    male   2.0      3      1   21.0750        S  NaN
# 8          1       3  female  27.0      0      2   11.1333        S  NaN
# 9          1       2  female  14.0      1      0   30.0708        C  NaN
# 10         1       3  female   4.0      1      1   16.7000        S    G
# 11         1       1  female  58.0      0      0   26.5500        S    C
# ...

# %%
titanic.set_index(["pclass",'sex'],inplace=True)#selected pclass and sex as an index(multiindexing)
titanic
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 3      male           0  22.0      1      0    7.2500        S  NaN
# 1      female         1  38.0      1      0   71.2833        C    C
# 3      female         1  26.0      0      0    7.9250        S  NaN
# 1      female         1  35.0      1      0   53.1000        S    C
# 3      male           0  35.0      0      0    8.0500        S  NaN
#        male           0   NaN      0      0    8.4583        Q  NaN
# 1      male           0  54.0      0      0   51.8625        S    E
# 3      male           0   2.0      3      1   21.0750        S  NaN
#        female         1  27.0      0      2   11.1333        S  NaN
# 2      female         1  14.0      1      0   30.0708        C  NaN
# 3      female         1   4.0      1      1   16.7000        S    G
# 1      female         1  58.0      0      0   26.5500        S    C
# 3      male           0  20.0      0      0    8.0500        S  NaN
# ...

# %%
titanic.sort_index()  #sorted the pclass index
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        male           0  54.0      0      0   51.8625        S    E
#        male           1  28.0      0      0   35.5000        S    A
#        male           0  19.0      3      2  263.0000        S    C
#        male           0  40.0      0      0   27.7208        C  NaN
#        male           0  28.0      1      0   82.1708        C  NaN
#        male           0  42.0      1      0   52.0000        S  NaN
# 2      female         1  14.0      1      0   30.0708        C  NaN
#        female         1  55.0      0      0   16.0000        S  NaN
#        female         0  27.0      1      0   21.0000        S  NaN
# ...

# %%
titanic.sort_index(ascending=[False,True])  #here pclass set as desceding order and sex as ascending order.
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 3      female         1  26.0      0      0    7.9250        S  NaN
#        female         1  27.0      0      2   11.1333        S  NaN
#        female         1   4.0      1      1   16.7000        S    G
#        female         0  14.0      0      0    7.8542        S  NaN
#        female         0  31.0      1      0   18.0000        S  NaN
#        female         1   NaN      0      0    7.2250        C  NaN
#        female         1  15.0      0      0    8.0292        Q  NaN
#        female         0   8.0      3      1   21.0750        S  NaN
#        female         1  38.0      1      5   31.3875        S  NaN
#        female         1   NaN      0      0    7.8792        Q  NaN
#        female         1   NaN      0      0    7.7500        Q  NaN
#        female         0  18.0      2      0   18.0000        S  NaN
#        female         1  14.0      1      0   11.2417        C  NaN
# ...

# %%
titanic.sort_index(ascending=[True,True])  #here pclass set as ascending order and sex as ascending order.
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        male           0  54.0      0      0   51.8625        S    E
#        male           1  28.0      0      0   35.5000        S    A
#        male           0  19.0      3      2  263.0000        S    C
#        male           0  40.0      0      0   27.7208        C  NaN
#        male           0  28.0      1      0   82.1708        C  NaN
#        male           0  42.0      1      0   52.0000        S  NaN
# 2      female         1  14.0      1      0   30.0708        C  NaN
#        female         1  55.0      0      0   16.0000        S  NaN
#        female         0  27.0      1      0   21.0000        S  NaN
# ...

# %%
titanic.swaplevel()  # swaplevel is used to swap the first index by second and vise versa.
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# sex    pclass
# male   3              0  22.0      1      0    7.2500        S  NaN
# female 1              1  38.0      1      0   71.2833        C    C
#        3              1  26.0      0      0    7.9250        S  NaN
#        1              1  35.0      1      0   53.1000        S    C
# male   3              0  35.0      0      0    8.0500        S  NaN
#        3              0   NaN      0      0    8.4583        Q  NaN
#        1              0  54.0      0      0   51.8625        S    E
#        3              0   2.0      3      1   21.0750        S  NaN
# female 3              1  27.0      0      2   11.1333        S  NaN
#        2              1  14.0      1      0   30.0708        C  NaN
#        3              1   4.0      1      1   16.7000        S    G
#        1              1  58.0      0      0   26.5500        S    C
# male   3              0  20.0      0      0    8.0500        S  NaN
# ...

# %%
titanic.reset_index(inplace=True)  #reset_index -to reset the index like original one.

# %%
titanic
# Out:
#     index  pclass     sex  survived   age  sibsp  parch      fare embarked  \
# 0       0       3    male         0  22.0      1      0    7.2500        S
# 1       1       1  female         1  38.0      1      0   71.2833        C
# 2       2       3  female         1  26.0      0      0    7.9250        S
# 3       3       1  female         1  35.0      1      0   53.1000        S
# 4       4       3    male         0  35.0      0      0    8.0500        S
# 5       5       3    male         0   NaN      0      0    8.4583        Q
# 6       6       1    male         0  54.0      0      0   51.8625        S
# 7       7       3    male         0   2.0      3      1   21.0750        S
# 8       8       3  female         1  27.0      0      2   11.1333        S
# 9       9       2  female         1  14.0      1      0   30.0708        C
# 10     10       3  female         1   4.0      1      1   16.7000        S
# ...

# %% [markdown]
# ### Hierarchical Indexing (Multiindex) (Part-2)

# %%
titanic=pd.read_csv('titanic.csv')

# %%
titanic=titanic.iloc[:50,]

# %%
titanic
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 0          0       3    male  22.0      1      0    7.2500        S  NaN
# 1          1       1  female  38.0      1      0   71.2833        C    C
# 2          1       3  female  26.0      0      0    7.9250        S  NaN
# 3          1       1  female  35.0      1      0   53.1000        S    C
# 4          0       3    male  35.0      0      0    8.0500        S  NaN
# 5          0       3    male   NaN      0      0    8.4583        Q  NaN
# 6          0       1    male  54.0      0      0   51.8625        S    E
# 7          0       3    male   2.0      3      1   21.0750        S  NaN
# 8          1       3  female  27.0      0      2   11.1333        S  NaN
# 9          1       2  female  14.0      1      0   30.0708        C  NaN
# 10         1       3  female   4.0      1      1   16.7000        S    G
# 11         1       1  female  58.0      0      0   26.5500        S    C
# ...

# %%
titanic=titanic.set_index(['pclass','sex']).sort_index(ascending=True)

# %%
titanic
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        male           0  54.0      0      0   51.8625        S    E
#        male           1  28.0      0      0   35.5000        S    A
#        male           0  19.0      3      2  263.0000        S    C
#        male           0  40.0      0      0   27.7208        C  NaN
#        male           0  28.0      1      0   82.1708        C  NaN
#        male           0  42.0      1      0   52.0000        S  NaN
# 2      female         1  14.0      1      0   30.0708        C  NaN
#        female         1  55.0      0      0   16.0000        S  NaN
#        female         0  27.0      1      0   21.0000        S  NaN
# ...

# %%
titanic.loc[1]
# Out:
#         survived   age  sibsp  parch      fare embarked deck
# sex
# female         1  38.0      1      0   71.2833        C    C
# female         1  35.0      1      0   53.1000        S    C
# female         1  58.0      0      0   26.5500        S    C
# female         1   NaN      1      0  146.5208        C    B
# male           0  54.0      0      0   51.8625        S    E
# male           1  28.0      0      0   35.5000        S    A
# male           0  19.0      3      2  263.0000        S    C
# male           0  40.0      0      0   27.7208        C  NaN
# male           0  28.0      1      0   82.1708        C  NaN
# male           0  42.0      1      0   52.0000        S  NaN

# %%
titanic.loc[[1,2]]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        male           0  54.0      0      0   51.8625        S    E
#        male           1  28.0      0      0   35.5000        S    A
#        male           0  19.0      3      2  263.0000        S    C
#        male           0  40.0      0      0   27.7208        C  NaN
#        male           0  28.0      1      0   82.1708        C  NaN
#        male           0  42.0      1      0   52.0000        S  NaN
# 2      female         1  14.0      1      0   30.0708        C  NaN
#        female         1  55.0      0      0   16.0000        S  NaN
#        female         0  27.0      1      0   21.0000        S  NaN
# ...

# %%
titanic.loc[:2]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        male           0  54.0      0      0   51.8625        S    E
#        male           1  28.0      0      0   35.5000        S    A
#        male           0  19.0      3      2  263.0000        S    C
#        male           0  40.0      0      0   27.7208        C  NaN
#        male           0  28.0      1      0   82.1708        C  NaN
#        male           0  42.0      1      0   52.0000        S  NaN
# 2      female         1  14.0      1      0   30.0708        C  NaN
#        female         1  55.0      0      0   16.0000        S  NaN
#        female         0  27.0      1      0   21.0000        S  NaN
# ...

# %%
titanic.loc[1,'female']
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B

# %%
titanic.loc[(1,'female'),'age']  # selecting the multi index labels inside the bracket and passing column labels
# Out:
# pclass  sex
# 1       female    38.0
#         female    35.0
#         female    58.0
#         female     NaN
# Name: age, dtype: float64

# %%
titanic.loc[([1,2],'female'),["age","fare"]]
# Out:
#                 age      fare
# pclass sex
# 1      female  38.0   71.2833
#        female  35.0   53.1000
#        female  58.0   26.5500
#        female   NaN  146.5208
# 2      female  14.0   30.0708
#        female  55.0   16.0000
#        female  27.0   21.0000
#        female   3.0   41.5792

# %%
titanic.loc[([1,2],'female'),:]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
# 2      female         1  14.0      1      0   30.0708        C  NaN
#        female         1  55.0      0      0   16.0000        S  NaN
#        female         0  27.0      1      0   21.0000        S  NaN
#        female         1   3.0      1      2   41.5792        C  NaN

# %%
titanic.loc[(:,'female'),:]  # slicing by only using : is not allowed in pandas specially at index position.
# Out:
#   File "<ipython-input-103-313eff819a0d>", line 1
#     titanic.loc[(:,'female'),:]
#                  ^
# SyntaxError: invalid syntax

# %%
titanic.loc[(slice(None),slice('female')),:] # the alternative- Use slice(None) instead of : and use slice('column') 
                                                # for sub-index and then select all rows.
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
# 2      female         1  14.0      1      0   30.0708        C  NaN
#        female         1  55.0      0      0   16.0000        S  NaN
#        female         0  27.0      1      0   21.0000        S  NaN
#        female         1   3.0      1      2   41.5792        C  NaN
# 3      female         1  26.0      0      0    7.9250        S  NaN
#        female         1  27.0      0      2   11.1333        S  NaN
#        female         1   4.0      1      1   16.7000        S    G
#        female         0  14.0      0      0    7.8542        S  NaN
#        female         0  31.0      1      0   18.0000        S  NaN
# ...

# %%
titanic.loc[(slice(1),slice('female')),:]  # Here we have selected 1 for first class in pclass columns.
                                        # So in general we can use this for safety in case od multiindexing.
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B

# %% [markdown]
# ### String Operations Intro/ Refresher Part -1

# %%
'Hello World'
# Out:
# 'Hello World'

# %%
type('Hello World')
# Out:
# str

# %%
hello= "Hello World"

# %%
len(hello)
# Out:
# 11

# %%
hello.upper()
# Out:
# 'HELLO WORLD'

# %%
hello.lower()
# Out:
# 'hello world'

# %%
hello.title()
# Out:
# 'Hello World'

# %%
hello.split(" ")#to split the sentence
# Out:
# ['Hello', 'World']

# %%
hello.replace("Hello","Hi") # To replace hello by hi
# Out:
# 'Hi World'

# %%
import pandas as pd

# %%
summer=pd.read_csv("summer.csv")
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
names=summer.loc[:9,'Athlete'].copy()

# %%
names
# Out:
# 0            HAJOS, Alfred
# 1         HERSCHMANN, Otto
# 2        DRIVAS, Dimitrios
# 3       MALOKINIS, Ioannis
# 4       CHASAPIS, Spiridon
# 5    CHOROPHAS, Efstathios
# 6            HAJOS, Alfred
# 7         ANDREOU, Joannis
# 8    CHOROPHAS, Efstathios
# 9            NEUMANN, Paul
# Name: Athlete, dtype: object

# %%
names.dtypes
# Out:
# dtype('O')

# %%
names[0]
# Out:
# 'HAJOS, Alfred'

# %%
type(names[0])
# Out:
# str

# %%
names.lower()  # Gives Error , whenever we try to apply string opertaion on string methods or pd dataframes
# we should .str to call strings
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-28392ba69b8a> in <module>
# ----> 1 names.lower()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
names.str.lower()
# Out:
# 0            hajos, alfred
# 1         herschmann, otto
# 2        drivas, dimitrios
# 3       malokinis, ioannis
# 4       chasapis, spiridon
# 5    chorophas, efstathios
# 6            hajos, alfred
# 7         andreou, joannis
# 8    chorophas, efstathios
# 9            neumann, paul
# Name: Athlete, dtype: object

# %% [markdown]
# ### String Operations Intro/ Refresher Part -2

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
names
# Out:
# 0            HAJOS, Alfred
# 1         HERSCHMANN, Otto
# 2        DRIVAS, Dimitrios
# 3       MALOKINIS, Ioannis
# 4       CHASAPIS, Spiridon
# 5    CHOROPHAS, Efstathios
# 6            HAJOS, Alfred
# 7         ANDREOU, Joannis
# 8    CHOROPHAS, Efstathios
# 9            NEUMANN, Paul
# Name: Athlete, dtype: object

# %%
names.str.lower()
# Out:
# 0            hajos, alfred
# 1         herschmann, otto
# 2        drivas, dimitrios
# 3       malokinis, ioannis
# 4       chasapis, spiridon
# 5    chorophas, efstathios
# 6            hajos, alfred
# 7         andreou, joannis
# 8    chorophas, efstathios
# 9            neumann, paul
# Name: Athlete, dtype: object

# %%
names.str.title()#title - Title case-i.e first character is capital.
# Out:
# 0            Hajos, Alfred
# 1         Herschmann, Otto
# 2        Drivas, Dimitrios
# 3       Malokinis, Ioannis
# 4       Chasapis, Spiridon
# 5    Chorophas, Efstathios
# 6            Hajos, Alfred
# 7         Andreou, Joannis
# 8    Chorophas, Efstathios
# 9            Neumann, Paul
# Name: Athlete, dtype: object

# %%
summer.Event.str.split(" ",n=2, expand=True)   #n=1,2   here 1,2,3 are wide spaces    #expnad= seperates into columns.summer
# Out:
#           0          1            2
# 0      100M  Freestyle         None
# 1      100M  Freestyle         None
# 2      100M  Freestyle  For Sailors
# 3      100M  Freestyle  For Sailors
# 4      100M  Freestyle  For Sailors
# ...     ...        ...          ...
# 31160    Wg         84           KG
# 31161    Wg         96           KG
# 31162    Wg         96           KG
# 31163    Wg         96           KG
# 31164    Wg         96           KG
#
# [31165 rows x 3 columns]

# %%
summer.Event.str.contains("100M")   #contains -used to get exact string in the columns.
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 31160    False
# 31161    False
# 31162    False
# 31163    False
# 31164    False
# Name: Event, Length: 31165, dtype: bool
